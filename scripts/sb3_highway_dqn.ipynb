# %% [markdown]
# # Highway with SB3's DQN
#
# ##  Warming up
# We start with a few useful installs and imports:

# %%
# Install environment and agent
# !pip install highway-env
# # TODO: we use the bleeding edge version because the current stable version does not support the latest gym>=0.21 versions. Revert back to stable at the next SB3 release.
# !pip install git+https://github.com/DLR-RM/stable-baselines3

# Environment
from utils import record_videos, show_videos
import gymnasium as gym
import highway_env


# Agent
from stable_baselines3 import DQN

# %load_ext tensorboard
import sys
from tqdm.notebook import trange
# !pip install tensorboardx gym pyvirtualdisplay
# !apt-get install -y xvfb ffmpeg
# !git clone https://github.com/Farama-Foundation/HighwayEnv.git 2> /dev/null
# sys.path.insert(0, '/content/highway-env/scripts/')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# d:\OneDrive\Studie\Embedded_Systems\Master_year_2\FAIP_IFEEMCS520100\Project\Highway_env_farma\HighwayEnv\scripts\sb3_highway_dqn.ipynb Cell 2 line 7
#       <a href='vscode-notebook-cell:/d%3A/OneDrive/Studie/Embedded_Systems/Master_year_2/FAIP_IFEEMCS520100/Project/Highway_env_farma/HighwayEnv/scripts/sb3_highway_dqn.ipynb#W1sZmlsZQ%3D%3D?line=0'>1</a> # Install environment and agent
#       <a href='vscode-notebook-cell:/d%3A/OneDrive/Studie/Embedded_Systems/Master_year_2/FAIP_IFEEMCS520100/Project/Highway_env_farma/HighwayEnv/scripts/sb3_highway_dqn.ipynb#W1sZmlsZQ%3D%3D?line=1'>2</a> # !pip install highway-env
#       <a href='vscode-notebook-cell:/d%3A/OneDrive/Studie/Embedded_Systems/Master_year_2/FAIP_IFEEMCS520100/Project/Highway_env_farma/HighwayEnv/scripts/sb3_highway_dqn.ipynb#W1sZmlsZQ%3D%3D?line=2'>3</a> # # TODO: we use the bleeding edge version because the current stable version does not support the latest gym>=0.21 versions. Revert back to stable at the next SB3 release.
#       <a href='vscode-notebook-cell:/d%3A/OneDrive/Studie/Embedded_Systems/Master_year_2/FAIP_IFEEMCS520100/Project/Highway_env_farma/HighwayEnv/scripts/sb3_highway_dqn.ipynb#W1sZmlsZQ%3D%3D?line=3'>4</a> # !pip install git+https://github.com/DLR-RM/stable-baselines3
#       <a href='vscode-notebook-cell:/d%3A/OneDrive/Studie/Embedded_Systems/Master_year_2/FAIP_IFEEMCS520100/Project/Highway_env_farma/HighwayEnv/scripts/sb3_highway_dqn.ipynb#W1sZmlsZQ%3D%3D?line=4'>5</a>
#       <a href='vscode-notebook-cell:/d%3A/OneDrive/Studie/Embedded_Systems/Master_year_2/FAIP_IFEEMCS520100/Project/Highway_env_farma/HighwayEnv/scripts/sb3_highway_dqn.ipynb#W1sZmlsZQ%3D%3D?line=5'>6</a> # Environment
# ----> <a href='vscode-notebook-cell:/d%3A/OneDrive/Studie/Embedded_Systems/Master_year_2/FAIP_IFEEMCS520100/Project/Highway_env_farma/HighwayEnv/scripts/sb3_highway_dqn.ipynb#W1sZmlsZQ%3D%3D?line=6'>7</a> from utils import record_videos, show_videos
#       <a href='vscode-notebook-cell:/d%3A/OneDrive/Studie/Embedded_Systems/Master_year_2/FAIP_IFEEMCS520100/Project/Highway_env_farma/HighwayEnv/scripts/sb3_highway_dqn.ipynb#W1sZmlsZQ%3D%3D?line=7'>8</a> import gymnasium as gym
#       <a href='vscode-notebook-cell:/d%3A/OneDrive/Studie/Embedded_Systems/Master_year_2/FAIP_IFEEMCS520100/Project/Highway_env_farma/HighwayEnv/scripts/sb3_highway_dqn.ipynb#W1sZmlsZQ%3D%3D?line=8'>9</a> import highway_env
#
# File d:\OneDrive\Studie\Embedded_Systems\Master_year_2\FAIP_IFEEMCS520100\Project\Highway_env_farma\HighwayEnv\scripts\utils.py:8
#       4 from pathlib import Path
#       5 import base64
# ----> 8 display = Display(visible=0, size=(1400, 900))
#       9 display.start()
#      12 def record_videos(env, video_folder="videos"):
#
# File c:\Users\Admin\anaconda3\envs\highway_env_dqn\lib\site-packages\pyvirtualdisplay\display.py:54, in Display.__init__(self, backend, visible, size, color_depth, bgcolor, use_xauth, retries, extra_args, manage_global_env, **kwargs)
#      51 if not cls:
#      52     raise ValueError("unknown backend: %s" % self._backend)
# ---> 54 self._obj = cls(
#      55     size=size,
#      56     color_depth=color_depth,
#      57     bgcolor=bgcolor,
#      58     retries=retries,
#      59     use_xauth=use_xauth,
#      60     # check_startup=check_startup,
#      61     extra_args=extra_args,
#      62     manage_global_env=manage_global_env,
#      63     **kwargs
#      64 )
#
# File c:\Users\Admin\anaconda3\envs\highway_env_dqn\lib\site-packages\pyvirtualdisplay\xvfb.py:44, in XvfbDisplay.__init__(self, size, color_depth, bgcolor, use_xauth, fbdir, dpi, retries, extra_args, manage_global_env)
#      41 self._fbdir = fbdir
#      42 self._dpi = dpi
# ---> 44 AbstractDisplay.__init__(
#      45     self,
#      46     PROGRAM,
#      47     use_xauth=use_xauth,
#      48     retries=retries,
#      49     extra_args=extra_args,
#      50     manage_global_env=manage_global_env,
#      51 )
#
# File c:\Users\Admin\anaconda3\envs\highway_env_dqn\lib\site-packages\pyvirtualdisplay\abstractdisplay.py:85, in AbstractDisplay.__init__(self, program, use_xauth, retries, extra_args, manage_global_env)
#      82 self._pipe_wfd = None
#      83 self._retries_current = 0
# ---> 85 helptext = get_helptext(program)
#      86 self._has_displayfd = "-displayfd" in helptext
#      87 if not self._has_displayfd:
#
# File c:\Users\Admin\anaconda3\envs\highway_env_dqn\lib\site-packages\pyvirtualdisplay\util.py:13, in get_helptext(program)
#       6 cmd = [program, "-help"]
#       8 # py3.7+
#       9 # p = subprocess.run(cmd, capture_output=True)
#      10 # stderr = p.stderr
#      11
#      12 # py3.6 also
# ---> 13 p = subprocess.Popen(
#      14     cmd,
#      15     stdout=subprocess.PIPE,
#      16     stderr=subprocess.PIPE,
#      17     shell=False,
#      18 )
#      19 _, stderr = p.communicate()
#      21 helptext = stderr.decode("utf-8", "ignore")
#
# File c:\Users\Admin\anaconda3\envs\highway_env_dqn\lib\subprocess.py:858, in Popen.__init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, encoding, errors, text)
#     854         if self.text_mode:
#     855             self.stderr = io.TextIOWrapper(self.stderr,
#     856                     encoding=encoding, errors=errors)
# --> 858     self._execute_child(args, executable, preexec_fn, close_fds,
#     859                         pass_fds, cwd, env,
#     860                         startupinfo, creationflags, shell,
#     861                         p2cread, p2cwrite,
#     862                         c2pread, c2pwrite,
#     863                         errread, errwrite,
#     864                         restore_signals, start_new_session)
#     865 except:
#     866     # Cleanup if the child failed starting.
#     867     for f in filter(None, (self.stdin, self.stdout, self.stderr)):
#
# File c:\Users\Admin\anaconda3\envs\highway_env_dqn\lib\subprocess.py:1327, in Popen._execute_child(self, args, executable, preexec_fn, close_fds, pass_fds, cwd, env, startupinfo, creationflags, shell, p2cread, p2cwrite, c2pread, c2pwrite, errread, errwrite, unused_restore_signals, unused_start_new_session)
#    1325 # Start the process
#    1326 try:
# -> 1327     hp, ht, pid, tid = _winapi.CreateProcess(executable, args,
#    1328                              # no special security
#    1329                              None, None,
#    1330                              int(not close_fds),
#    1331                              creationflags,
#    1332                              env,
#    1333                              cwd,
#    1334                              startupinfo)
#    1335 finally:
#    1336     # Child is launched. Close the parent's copy of those pipe
#    1337     # handles that only the child should have open.  You need
#    (...)
#    1340     # pipe will not close when the child process exits and the
#    1341     # ReadFile will hang.
#    1342     self._close_pipe_fds(p2cread, p2cwrite,
#    1343                          c2pread, c2pwrite,
#    1344                          errread, errwrite)
#
# File c:\Users\Admin\anaconda3\envs\highway_env_dqn\lib\site-packages\debugpy\_vendored\pydevd\_pydev_bundle\pydev_monkey.py:901, in create_CreateProcess.<locals>.new_CreateProcess(app_name, cmd_line, *args)
#     898     cmd_line = patch_arg_str_win(cmd_line)
#     899     send_process_created_message()
# --> 901 return getattr(_subprocess, original_name)(app_name, cmd_line, *args)
#
# FileNotFoundError: [WinError 2] Het systeem kan het opgegeven bestand niet vinden

# %% [markdown]
# ## Training
# Run tensorboard locally to visualize training.

# %%
# %tensorboard --logdir "highway_dqn"
# Out:
# Reusing TensorBoard on port 6006 (pid 93096), started 0:05:40 ago. (Use '!kill 93096' to kill it.)
#       <iframe id="tensorboard-frame-6e0bd018263b764" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-6e0bd018263b764");
#           const url = new URL("http://localhost");
#           const port = 6006;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %%
model = DQN('MlpPolicy', 'highway-fast-v0',
                policy_kwargs=dict(net_arch=[256, 256]),
                learning_rate=5e-4,
                buffer_size=15000,
                learning_starts=200,
                batch_size=32,
                gamma=0.8,
                train_freq=1,
                gradient_steps=1,
                target_update_interval=50,
                exploration_fraction=0.7,
                verbose=1,
                tensorboard_log='highway_dqn/')
model.learn(int(2e4))
# Out:
# Using cuda device
# Creating environment from the given name 'highway-fast-v0'
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Logging to highway_dqn/DQN_12
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13       |
# |    ep_rew_mean      | 10       |
# |    exploration_rate | 0.996    |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 16       |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 52       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 13.5     |
# |    ep_rew_mean      | 10.2     |
# |    exploration_rate | 0.993    |
# | time/               |          |
# |    episodes         | 8        |
# |    fps              | 16       |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 108      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 12.8     |
# |    ep_rew_mean      | 9.93     |
# |    exploration_rate | 0.99     |
# | time/               |          |
# |    episodes         | 12       |
# |    fps              | 16       |
# |    time_elapsed     | 9        |
# |    total_timesteps  | 153      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 12.8     |
# |    ep_rew_mean      | 9.77     |
# |    exploration_rate | 0.986    |
# | time/               |          |
# |    episodes         | 16       |
# |    fps              | 16       |
# |    time_elapsed     | 12       |
# |    total_timesteps  | 205      |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.298    |
# |    n_updates        | 4        |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 12.6     |
# |    ep_rew_mean      | 9.52     |
# |    exploration_rate | 0.983    |
# | time/               |          |
# |    episodes         | 20       |
# |    fps              | 16       |
# |    time_elapsed     | 14       |
# |    total_timesteps  | 251      |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.29     |
# |    n_updates        | 50       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 12.4     |
# |    ep_rew_mean      | 9.39     |
# |    exploration_rate | 0.98     |
# | time/               |          |
# |    episodes         | 24       |
# |    fps              | 16       |
# |    time_elapsed     | 17       |
# |    total_timesteps  | 298      |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0858   |
# |    n_updates        | 97       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 12.8     |
# |    ep_rew_mean      | 9.62     |
# |    exploration_rate | 0.976    |
# | time/               |          |
# |    episodes         | 28       |
# |    fps              | 16       |
# |    time_elapsed     | 21       |
# |    total_timesteps  | 359      |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.234    |
# |    n_updates        | 158      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 12.9     |
# |    ep_rew_mean      | 9.7      |
# |    exploration_rate | 0.972    |
# | time/               |          |
# |    episodes         | 32       |
# |    fps              | 16       |
# |    time_elapsed     | 24       |
# |    total_timesteps  | 414      |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.147    |
# |    n_updates        | 213      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.9     |
# |    ep_rew_mean      | 8.92     |
# |    exploration_rate | 0.971    |
# | time/               |          |
# |    episodes         | 36       |
# |    fps              | 16       |
# |    time_elapsed     | 25       |
# |    total_timesteps  | 430      |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0677   |
# |    n_updates        | 229      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.7     |
# |    ep_rew_mean      | 8.76     |
# |    exploration_rate | 0.968    |
# | time/               |          |
# |    episodes         | 40       |
# |    fps              | 16       |
# |    time_elapsed     | 28       |
# |    total_timesteps  | 469      |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.386    |
# |    n_updates        | 268      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.8     |
# |    ep_rew_mean      | 8.83     |
# |    exploration_rate | 0.965    |
# | time/               |          |
# |    episodes         | 44       |
# |    fps              | 16       |
# |    time_elapsed     | 30       |
# |    total_timesteps  | 518      |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.404    |
# |    n_updates        | 317      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.7     |
# |    ep_rew_mean      | 8.75     |
# |    exploration_rate | 0.962    |
# | time/               |          |
# |    episodes         | 48       |
# |    fps              | 16       |
# |    time_elapsed     | 33       |
# |    total_timesteps  | 561      |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0936   |
# |    n_updates        | 360      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.9     |
# |    ep_rew_mean      | 8.91     |
# |    exploration_rate | 0.958    |
# | time/               |          |
# |    episodes         | 52       |
# |    fps              | 16       |
# |    time_elapsed     | 37       |
# |    total_timesteps  | 618      |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.268    |
# |    n_updates        | 417      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 12       |
# |    ep_rew_mean      | 9.05     |
# |    exploration_rate | 0.954    |
# | time/               |          |
# |    episodes         | 56       |
# |    fps              | 16       |
# |    time_elapsed     | 40       |
# |    total_timesteps  | 674      |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.00846  |
# |    n_updates        | 473      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.8     |
# |    ep_rew_mean      | 8.89     |
# |    exploration_rate | 0.952    |
# | time/               |          |
# |    episodes         | 60       |
# |    fps              | 16       |
# |    time_elapsed     | 42       |
# |    total_timesteps  | 708      |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.545    |
# |    n_updates        | 507      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.5     |
# |    ep_rew_mean      | 8.6      |
# |    exploration_rate | 0.95     |
# | time/               |          |
# |    episodes         | 64       |
# |    fps              | 16       |
# |    time_elapsed     | 44       |
# |    total_timesteps  | 734      |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.201    |
# |    n_updates        | 533      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.2     |
# |    ep_rew_mean      | 8.39     |
# |    exploration_rate | 0.948    |
# | time/               |          |
# |    episodes         | 68       |
# |    fps              | 16       |
# |    time_elapsed     | 45       |
# |    total_timesteps  | 760      |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.115    |
# |    n_updates        | 559      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.3     |
# |    ep_rew_mean      | 8.48     |
# |    exploration_rate | 0.945    |
# | time/               |          |
# |    episodes         | 72       |
# |    fps              | 16       |
# |    time_elapsed     | 48       |
# |    total_timesteps  | 811      |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.589    |
# |    n_updates        | 610      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.3     |
# |    ep_rew_mean      | 8.51     |
# |    exploration_rate | 0.942    |
# | time/               |          |
# |    episodes         | 76       |
# |    fps              | 16       |
# |    time_elapsed     | 51       |
# |    total_timesteps  | 859      |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.102    |
# |    n_updates        | 658      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.3     |
# |    ep_rew_mean      | 8.58     |
# |    exploration_rate | 0.938    |
# | time/               |          |
# |    episodes         | 80       |
# |    fps              | 16       |
# |    time_elapsed     | 54       |
# |    total_timesteps  | 907      |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.177    |
# |    n_updates        | 706      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.5     |
# |    ep_rew_mean      | 8.74     |
# |    exploration_rate | 0.934    |
# | time/               |          |
# |    episodes         | 84       |
# |    fps              | 16       |
# |    time_elapsed     | 58       |
# |    total_timesteps  | 969      |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.234    |
# |    n_updates        | 768      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.3     |
# |    ep_rew_mean      | 8.58     |
# |    exploration_rate | 0.932    |
# | time/               |          |
# |    episodes         | 88       |
# |    fps              | 16       |
# |    time_elapsed     | 59       |
# |    total_timesteps  | 996      |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.292    |
# |    n_updates        | 795      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.5     |
# |    ep_rew_mean      | 8.71     |
# |    exploration_rate | 0.928    |
# | time/               |          |
# |    episodes         | 92       |
# |    fps              | 16       |
# |    time_elapsed     | 63       |
# |    total_timesteps  | 1058     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.117    |
# |    n_updates        | 857      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.4     |
# |    ep_rew_mean      | 8.63     |
# |    exploration_rate | 0.926    |
# | time/               |          |
# |    episodes         | 96       |
# |    fps              | 16       |
# |    time_elapsed     | 65       |
# |    total_timesteps  | 1095     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.305    |
# |    n_updates        | 894      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.3     |
# |    ep_rew_mean      | 8.56     |
# |    exploration_rate | 0.923    |
# | time/               |          |
# |    episodes         | 100      |
# |    fps              | 16       |
# |    time_elapsed     | 67       |
# |    total_timesteps  | 1132     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.131    |
# |    n_updates        | 931      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.4     |
# |    ep_rew_mean      | 8.58     |
# |    exploration_rate | 0.919    |
# | time/               |          |
# |    episodes         | 104      |
# |    fps              | 16       |
# |    time_elapsed     | 71       |
# |    total_timesteps  | 1191     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.213    |
# |    n_updates        | 990      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.4     |
# |    ep_rew_mean      | 8.56     |
# |    exploration_rate | 0.916    |
# | time/               |          |
# |    episodes         | 108      |
# |    fps              | 16       |
# |    time_elapsed     | 74       |
# |    total_timesteps  | 1244     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.118    |
# |    n_updates        | 1043     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.7     |
# |    ep_rew_mean      | 8.81     |
# |    exploration_rate | 0.91     |
# | time/               |          |
# |    episodes         | 112      |
# |    fps              | 16       |
# |    time_elapsed     | 79       |
# |    total_timesteps  | 1322     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.279    |
# |    n_updates        | 1121     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.5     |
# |    ep_rew_mean      | 8.68     |
# |    exploration_rate | 0.908    |
# | time/               |          |
# |    episodes         | 116      |
# |    fps              | 16       |
# |    time_elapsed     | 81       |
# |    total_timesteps  | 1354     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.255    |
# |    n_updates        | 1153     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.3     |
# |    ep_rew_mean      | 8.54     |
# |    exploration_rate | 0.906    |
# | time/               |          |
# |    episodes         | 120      |
# |    fps              | 16       |
# |    time_elapsed     | 83       |
# |    total_timesteps  | 1381     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.212    |
# |    n_updates        | 1180     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.5     |
# |    ep_rew_mean      | 8.7      |
# |    exploration_rate | 0.902    |
# | time/               |          |
# |    episodes         | 124      |
# |    fps              | 16       |
# |    time_elapsed     | 87       |
# |    total_timesteps  | 1448     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.311    |
# |    n_updates        | 1247     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.6     |
# |    ep_rew_mean      | 8.77     |
# |    exploration_rate | 0.897    |
# | time/               |          |
# |    episodes         | 128      |
# |    fps              | 16       |
# |    time_elapsed     | 91       |
# |    total_timesteps  | 1518     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.516    |
# |    n_updates        | 1317     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.4     |
# |    ep_rew_mean      | 8.66     |
# |    exploration_rate | 0.894    |
# | time/               |          |
# |    episodes         | 132      |
# |    fps              | 16       |
# |    time_elapsed     | 94       |
# |    total_timesteps  | 1558     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.107    |
# |    n_updates        | 1357     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.7     |
# |    ep_rew_mean      | 8.85     |
# |    exploration_rate | 0.892    |
# | time/               |          |
# |    episodes         | 136      |
# |    fps              | 16       |
# |    time_elapsed     | 96       |
# |    total_timesteps  | 1598     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.115    |
# |    n_updates        | 1397     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.6     |
# |    ep_rew_mean      | 8.78     |
# |    exploration_rate | 0.89     |
# | time/               |          |
# |    episodes         | 140      |
# |    fps              | 16       |
# |    time_elapsed     | 98       |
# |    total_timesteps  | 1628     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.109    |
# |    n_updates        | 1427     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.4     |
# |    ep_rew_mean      | 8.65     |
# |    exploration_rate | 0.887    |
# | time/               |          |
# |    episodes         | 144      |
# |    fps              | 16       |
# |    time_elapsed     | 100      |
# |    total_timesteps  | 1661     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.204    |
# |    n_updates        | 1460     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.7     |
# |    ep_rew_mean      | 8.88     |
# |    exploration_rate | 0.883    |
# | time/               |          |
# |    episodes         | 148      |
# |    fps              | 16       |
# |    time_elapsed     | 104      |
# |    total_timesteps  | 1728     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.385    |
# |    n_updates        | 1527     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.5     |
# |    ep_rew_mean      | 8.78     |
# |    exploration_rate | 0.88     |
# | time/               |          |
# |    episodes         | 152      |
# |    fps              | 16       |
# |    time_elapsed     | 106      |
# |    total_timesteps  | 1772     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0162   |
# |    n_updates        | 1571     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.4     |
# |    ep_rew_mean      | 8.66     |
# |    exploration_rate | 0.877    |
# | time/               |          |
# |    episodes         | 156      |
# |    fps              | 16       |
# |    time_elapsed     | 109      |
# |    total_timesteps  | 1812     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.208    |
# |    n_updates        | 1611     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.5     |
# |    ep_rew_mean      | 8.72     |
# |    exploration_rate | 0.874    |
# | time/               |          |
# |    episodes         | 160      |
# |    fps              | 16       |
# |    time_elapsed     | 111      |
# |    total_timesteps  | 1854     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.282    |
# |    n_updates        | 1653     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.7     |
# |    ep_rew_mean      | 8.95     |
# |    exploration_rate | 0.871    |
# | time/               |          |
# |    episodes         | 164      |
# |    fps              | 16       |
# |    time_elapsed     | 114      |
# |    total_timesteps  | 1908     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.128    |
# |    n_updates        | 1707     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 12.2     |
# |    ep_rew_mean      | 9.27     |
# |    exploration_rate | 0.866    |
# | time/               |          |
# |    episodes         | 168      |
# |    fps              | 16       |
# |    time_elapsed     | 118      |
# |    total_timesteps  | 1977     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.205    |
# |    n_updates        | 1776     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 12.1     |
# |    ep_rew_mean      | 9.21     |
# |    exploration_rate | 0.863    |
# | time/               |          |
# |    episodes         | 172      |
# |    fps              | 16       |
# |    time_elapsed     | 121      |
# |    total_timesteps  | 2022     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.154    |
# |    n_updates        | 1821     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 12.2     |
# |    ep_rew_mean      | 9.23     |
# |    exploration_rate | 0.859    |
# | time/               |          |
# |    episodes         | 176      |
# |    fps              | 16       |
# |    time_elapsed     | 124      |
# |    total_timesteps  | 2075     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.218    |
# |    n_updates        | 1874     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.9     |
# |    ep_rew_mean      | 8.99     |
# |    exploration_rate | 0.858    |
# | time/               |          |
# |    episodes         | 180      |
# |    fps              | 16       |
# |    time_elapsed     | 126      |
# |    total_timesteps  | 2096     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.401    |
# |    n_updates        | 1895     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.7     |
# |    ep_rew_mean      | 8.83     |
# |    exploration_rate | 0.855    |
# | time/               |          |
# |    episodes         | 184      |
# |    fps              | 16       |
# |    time_elapsed     | 129      |
# |    total_timesteps  | 2137     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0332   |
# |    n_updates        | 1936     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 12       |
# |    ep_rew_mean      | 9.04     |
# |    exploration_rate | 0.851    |
# | time/               |          |
# |    episodes         | 188      |
# |    fps              | 16       |
# |    time_elapsed     | 132      |
# |    total_timesteps  | 2192     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.376    |
# |    n_updates        | 1991     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.7     |
# |    ep_rew_mean      | 8.83     |
# |    exploration_rate | 0.849    |
# | time/               |          |
# |    episodes         | 192      |
# |    fps              | 16       |
# |    time_elapsed     | 134      |
# |    total_timesteps  | 2225     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0907   |
# |    n_updates        | 2024     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.8     |
# |    ep_rew_mean      | 8.92     |
# |    exploration_rate | 0.846    |
# | time/               |          |
# |    episodes         | 196      |
# |    fps              | 16       |
# |    time_elapsed     | 137      |
# |    total_timesteps  | 2274     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0185   |
# |    n_updates        | 2073     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.9     |
# |    ep_rew_mean      | 9.05     |
# |    exploration_rate | 0.842    |
# | time/               |          |
# |    episodes         | 200      |
# |    fps              | 16       |
# |    time_elapsed     | 140      |
# |    total_timesteps  | 2327     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.076    |
# |    n_updates        | 2126     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.7     |
# |    ep_rew_mean      | 8.9      |
# |    exploration_rate | 0.84     |
# | time/               |          |
# |    episodes         | 204      |
# |    fps              | 16       |
# |    time_elapsed     | 142      |
# |    total_timesteps  | 2361     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.23     |
# |    n_updates        | 2160     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.7     |
# |    ep_rew_mean      | 8.87     |
# |    exploration_rate | 0.836    |
# | time/               |          |
# |    episodes         | 208      |
# |    fps              | 16       |
# |    time_elapsed     | 146      |
# |    total_timesteps  | 2413     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.217    |
# |    n_updates        | 2212     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.7     |
# |    ep_rew_mean      | 8.89     |
# |    exploration_rate | 0.831    |
# | time/               |          |
# |    episodes         | 212      |
# |    fps              | 16       |
# |    time_elapsed     | 151      |
# |    total_timesteps  | 2495     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0175   |
# |    n_updates        | 2294     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.6     |
# |    ep_rew_mean      | 8.81     |
# |    exploration_rate | 0.829    |
# | time/               |          |
# |    episodes         | 216      |
# |    fps              | 16       |
# |    time_elapsed     | 152      |
# |    total_timesteps  | 2516     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.547    |
# |    n_updates        | 2315     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.8     |
# |    ep_rew_mean      | 8.92     |
# |    exploration_rate | 0.826    |
# | time/               |          |
# |    episodes         | 220      |
# |    fps              | 16       |
# |    time_elapsed     | 155      |
# |    total_timesteps  | 2558     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.306    |
# |    n_updates        | 2357     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.5     |
# |    ep_rew_mean      | 8.72     |
# |    exploration_rate | 0.824    |
# | time/               |          |
# |    episodes         | 224      |
# |    fps              | 16       |
# |    time_elapsed     | 158      |
# |    total_timesteps  | 2598     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.421    |
# |    n_updates        | 2397     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.4     |
# |    ep_rew_mean      | 8.64     |
# |    exploration_rate | 0.82     |
# | time/               |          |
# |    episodes         | 228      |
# |    fps              | 16       |
# |    time_elapsed     | 161      |
# |    total_timesteps  | 2657     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.161    |
# |    n_updates        | 2456     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.3     |
# |    ep_rew_mean      | 8.63     |
# |    exploration_rate | 0.817    |
# | time/               |          |
# |    episodes         | 232      |
# |    fps              | 16       |
# |    time_elapsed     | 164      |
# |    total_timesteps  | 2693     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.295    |
# |    n_updates        | 2492     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.4     |
# |    ep_rew_mean      | 8.66     |
# |    exploration_rate | 0.814    |
# | time/               |          |
# |    episodes         | 236      |
# |    fps              | 16       |
# |    time_elapsed     | 166      |
# |    total_timesteps  | 2737     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.178    |
# |    n_updates        | 2536     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.4     |
# |    ep_rew_mean      | 8.67     |
# |    exploration_rate | 0.812    |
# | time/               |          |
# |    episodes         | 240      |
# |    fps              | 16       |
# |    time_elapsed     | 168      |
# |    total_timesteps  | 2768     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.394    |
# |    n_updates        | 2567     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.8     |
# |    ep_rew_mean      | 8.94     |
# |    exploration_rate | 0.807    |
# | time/               |          |
# |    episodes         | 244      |
# |    fps              | 16       |
# |    time_elapsed     | 172      |
# |    total_timesteps  | 2838     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.206    |
# |    n_updates        | 2637     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.6     |
# |    ep_rew_mean      | 8.73     |
# |    exploration_rate | 0.804    |
# | time/               |          |
# |    episodes         | 248      |
# |    fps              | 16       |
# |    time_elapsed     | 175      |
# |    total_timesteps  | 2883     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.491    |
# |    n_updates        | 2682     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.3     |
# |    ep_rew_mean      | 8.54     |
# |    exploration_rate | 0.803    |
# | time/               |          |
# |    episodes         | 252      |
# |    fps              | 16       |
# |    time_elapsed     | 176      |
# |    total_timesteps  | 2902     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.201    |
# |    n_updates        | 2701     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.3     |
# |    ep_rew_mean      | 8.52     |
# |    exploration_rate | 0.8      |
# | time/               |          |
# |    episodes         | 256      |
# |    fps              | 16       |
# |    time_elapsed     | 179      |
# |    total_timesteps  | 2942     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.307    |
# |    n_updates        | 2741     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.4     |
# |    ep_rew_mean      | 8.61     |
# |    exploration_rate | 0.797    |
# | time/               |          |
# |    episodes         | 260      |
# |    fps              | 16       |
# |    time_elapsed     | 182      |
# |    total_timesteps  | 2996     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.409    |
# |    n_updates        | 2795     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.3     |
# |    ep_rew_mean      | 8.53     |
# |    exploration_rate | 0.794    |
# | time/               |          |
# |    episodes         | 264      |
# |    fps              | 16       |
# |    time_elapsed     | 184      |
# |    total_timesteps  | 3040     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.559    |
# |    n_updates        | 2839     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.2     |
# |    ep_rew_mean      | 8.44     |
# |    exploration_rate | 0.79     |
# | time/               |          |
# |    episodes         | 268      |
# |    fps              | 16       |
# |    time_elapsed     | 188      |
# |    total_timesteps  | 3097     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.446    |
# |    n_updates        | 2896     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.2     |
# |    ep_rew_mean      | 8.41     |
# |    exploration_rate | 0.787    |
# | time/               |          |
# |    episodes         | 272      |
# |    fps              | 16       |
# |    time_elapsed     | 190      |
# |    total_timesteps  | 3139     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.165    |
# |    n_updates        | 2938     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.1     |
# |    ep_rew_mean      | 8.35     |
# |    exploration_rate | 0.784    |
# | time/               |          |
# |    episodes         | 276      |
# |    fps              | 16       |
# |    time_elapsed     | 193      |
# |    total_timesteps  | 3185     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.194    |
# |    n_updates        | 2984     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.4     |
# |    ep_rew_mean      | 8.59     |
# |    exploration_rate | 0.78     |
# | time/               |          |
# |    episodes         | 280      |
# |    fps              | 16       |
# |    time_elapsed     | 196      |
# |    total_timesteps  | 3235     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0294   |
# |    n_updates        | 3034     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.3     |
# |    ep_rew_mean      | 8.45     |
# |    exploration_rate | 0.779    |
# | time/               |          |
# |    episodes         | 284      |
# |    fps              | 16       |
# |    time_elapsed     | 198      |
# |    total_timesteps  | 3263     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.1      |
# |    n_updates        | 3062     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.1     |
# |    ep_rew_mean      | 8.36     |
# |    exploration_rate | 0.776    |
# | time/               |          |
# |    episodes         | 288      |
# |    fps              | 16       |
# |    time_elapsed     | 200      |
# |    total_timesteps  | 3303     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.191    |
# |    n_updates        | 3102     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.3     |
# |    ep_rew_mean      | 8.5      |
# |    exploration_rate | 0.772    |
# | time/               |          |
# |    episodes         | 292      |
# |    fps              | 16       |
# |    time_elapsed     | 203      |
# |    total_timesteps  | 3354     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0207   |
# |    n_updates        | 3153     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.2     |
# |    ep_rew_mean      | 8.44     |
# |    exploration_rate | 0.77     |
# | time/               |          |
# |    episodes         | 296      |
# |    fps              | 16       |
# |    time_elapsed     | 205      |
# |    total_timesteps  | 3392     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.153    |
# |    n_updates        | 3191     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11       |
# |    ep_rew_mean      | 8.28     |
# |    exploration_rate | 0.768    |
# | time/               |          |
# |    episodes         | 300      |
# |    fps              | 16       |
# |    time_elapsed     | 207      |
# |    total_timesteps  | 3425     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.448    |
# |    n_updates        | 3224     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.9     |
# |    ep_rew_mean      | 8.21     |
# |    exploration_rate | 0.766    |
# | time/               |          |
# |    episodes         | 304      |
# |    fps              | 16       |
# |    time_elapsed     | 209      |
# |    total_timesteps  | 3453     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.47     |
# |    n_updates        | 3252     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.9     |
# |    ep_rew_mean      | 8.21     |
# |    exploration_rate | 0.763    |
# | time/               |          |
# |    episodes         | 308      |
# |    fps              | 16       |
# |    time_elapsed     | 212      |
# |    total_timesteps  | 3499     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.476    |
# |    n_updates        | 3298     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.6     |
# |    ep_rew_mean      | 8        |
# |    exploration_rate | 0.759    |
# | time/               |          |
# |    episodes         | 312      |
# |    fps              | 16       |
# |    time_elapsed     | 215      |
# |    total_timesteps  | 3551     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.343    |
# |    n_updates        | 3350     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.1     |
# |    ep_rew_mean      | 8.43     |
# |    exploration_rate | 0.754    |
# | time/               |          |
# |    episodes         | 316      |
# |    fps              | 16       |
# |    time_elapsed     | 219      |
# |    total_timesteps  | 3629     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0344   |
# |    n_updates        | 3428     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.1     |
# |    ep_rew_mean      | 8.42     |
# |    exploration_rate | 0.751    |
# | time/               |          |
# |    episodes         | 320      |
# |    fps              | 16       |
# |    time_elapsed     | 221      |
# |    total_timesteps  | 3667     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.216    |
# |    n_updates        | 3466     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.3     |
# |    ep_rew_mean      | 8.56     |
# |    exploration_rate | 0.747    |
# | time/               |          |
# |    episodes         | 324      |
# |    fps              | 16       |
# |    time_elapsed     | 225      |
# |    total_timesteps  | 3726     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.379    |
# |    n_updates        | 3525     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11       |
# |    ep_rew_mean      | 8.4      |
# |    exploration_rate | 0.745    |
# | time/               |          |
# |    episodes         | 328      |
# |    fps              | 16       |
# |    time_elapsed     | 227      |
# |    total_timesteps  | 3761     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.275    |
# |    n_updates        | 3560     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.1     |
# |    ep_rew_mean      | 8.44     |
# |    exploration_rate | 0.742    |
# | time/               |          |
# |    episodes         | 332      |
# |    fps              | 16       |
# |    time_elapsed     | 229      |
# |    total_timesteps  | 3804     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.291    |
# |    n_updates        | 3603     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.1     |
# |    ep_rew_mean      | 8.39     |
# |    exploration_rate | 0.739    |
# | time/               |          |
# |    episodes         | 336      |
# |    fps              | 16       |
# |    time_elapsed     | 231      |
# |    total_timesteps  | 3843     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.263    |
# |    n_updates        | 3642     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.1     |
# |    ep_rew_mean      | 8.4      |
# |    exploration_rate | 0.737    |
# | time/               |          |
# |    episodes         | 340      |
# |    fps              | 16       |
# |    time_elapsed     | 233      |
# |    total_timesteps  | 3878     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0137   |
# |    n_updates        | 3677     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.2     |
# |    ep_rew_mean      | 8.47     |
# |    exploration_rate | 0.732    |
# | time/               |          |
# |    episodes         | 344      |
# |    fps              | 16       |
# |    time_elapsed     | 238      |
# |    total_timesteps  | 3956     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.206    |
# |    n_updates        | 3755     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.3     |
# |    ep_rew_mean      | 8.57     |
# |    exploration_rate | 0.727    |
# | time/               |          |
# |    episodes         | 348      |
# |    fps              | 16       |
# |    time_elapsed     | 242      |
# |    total_timesteps  | 4016     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.096    |
# |    n_updates        | 3815     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.7     |
# |    ep_rew_mean      | 8.87     |
# |    exploration_rate | 0.724    |
# | time/               |          |
# |    episodes         | 352      |
# |    fps              | 16       |
# |    time_elapsed     | 245      |
# |    total_timesteps  | 4071     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0876   |
# |    n_updates        | 3870     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 12       |
# |    ep_rew_mean      | 9.09     |
# |    exploration_rate | 0.719    |
# | time/               |          |
# |    episodes         | 356      |
# |    fps              | 16       |
# |    time_elapsed     | 249      |
# |    total_timesteps  | 4141     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.26     |
# |    n_updates        | 3940     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 12       |
# |    ep_rew_mean      | 9.08     |
# |    exploration_rate | 0.715    |
# | time/               |          |
# |    episodes         | 360      |
# |    fps              | 16       |
# |    time_elapsed     | 252      |
# |    total_timesteps  | 4195     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.129    |
# |    n_updates        | 3994     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 12.3     |
# |    ep_rew_mean      | 9.36     |
# |    exploration_rate | 0.71     |
# | time/               |          |
# |    episodes         | 364      |
# |    fps              | 16       |
# |    time_elapsed     | 257      |
# |    total_timesteps  | 4275     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.397    |
# |    n_updates        | 4074     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 12.2     |
# |    ep_rew_mean      | 9.32     |
# |    exploration_rate | 0.707    |
# | time/               |          |
# |    episodes         | 368      |
# |    fps              | 16       |
# |    time_elapsed     | 260      |
# |    total_timesteps  | 4322     |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0958   |
# ...
# |    time_elapsed     | 1064     |
# |    total_timesteps  | 17335    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0892   |
# |    n_updates        | 17134    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22.3     |
# |    ep_rew_mean      | 18.2     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1096     |
# |    fps              | 16       |
# |    time_elapsed     | 1070     |
# |    total_timesteps  | 17427    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.085    |
# |    n_updates        | 17226    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.7     |
# |    ep_rew_mean      | 17.7     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1100     |
# |    fps              | 16       |
# |    time_elapsed     | 1073     |
# |    total_timesteps  | 17475    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.172    |
# |    n_updates        | 17274    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22.4     |
# |    ep_rew_mean      | 18.3     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1104     |
# |    fps              | 16       |
# |    time_elapsed     | 1080     |
# |    total_timesteps  | 17591    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0295   |
# |    n_updates        | 17390    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22.3     |
# |    ep_rew_mean      | 18.1     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1108     |
# |    fps              | 16       |
# |    time_elapsed     | 1084     |
# |    total_timesteps  | 17667    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0316   |
# |    n_updates        | 17466    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22.3     |
# |    ep_rew_mean      | 18.1     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1112     |
# |    fps              | 16       |
# |    time_elapsed     | 1090     |
# |    total_timesteps  | 17759    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.237    |
# |    n_updates        | 17558    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22.8     |
# |    ep_rew_mean      | 18.5     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1116     |
# |    fps              | 16       |
# |    time_elapsed     | 1096     |
# |    total_timesteps  | 17865    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.199    |
# |    n_updates        | 17664    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 23       |
# |    ep_rew_mean      | 18.7     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1120     |
# |    fps              | 16       |
# |    time_elapsed     | 1101     |
# |    total_timesteps  | 17953    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0257   |
# |    n_updates        | 17752    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22.8     |
# |    ep_rew_mean      | 18.5     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1124     |
# |    fps              | 16       |
# |    time_elapsed     | 1106     |
# |    total_timesteps  | 18030    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0911   |
# |    n_updates        | 17829    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22.8     |
# |    ep_rew_mean      | 18.6     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1128     |
# |    fps              | 16       |
# |    time_elapsed     | 1112     |
# |    total_timesteps  | 18135    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.243    |
# |    n_updates        | 17934    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22.4     |
# |    ep_rew_mean      | 18.2     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1132     |
# |    fps              | 16       |
# |    time_elapsed     | 1115     |
# |    total_timesteps  | 18181    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0254   |
# |    n_updates        | 17980    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22.3     |
# |    ep_rew_mean      | 18.1     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1136     |
# |    fps              | 16       |
# |    time_elapsed     | 1117     |
# |    total_timesteps  | 18215    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.107    |
# |    n_updates        | 18014    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22.2     |
# |    ep_rew_mean      | 18.1     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1140     |
# |    fps              | 16       |
# |    time_elapsed     | 1125     |
# |    total_timesteps  | 18332    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.188    |
# |    n_updates        | 18131    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.7     |
# |    ep_rew_mean      | 17.7     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1144     |
# |    fps              | 16       |
# |    time_elapsed     | 1129     |
# |    total_timesteps  | 18394    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.202    |
# |    n_updates        | 18193    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.2     |
# |    ep_rew_mean      | 17.3     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1148     |
# |    fps              | 16       |
# |    time_elapsed     | 1134     |
# |    total_timesteps  | 18465    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.132    |
# |    n_updates        | 18264    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.1     |
# |    ep_rew_mean      | 17.2     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1152     |
# |    fps              | 16       |
# |    time_elapsed     | 1139     |
# |    total_timesteps  | 18554    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0159   |
# |    n_updates        | 18353    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.4     |
# |    ep_rew_mean      | 17.5     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1156     |
# |    fps              | 16       |
# |    time_elapsed     | 1146     |
# |    total_timesteps  | 18661    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.172    |
# |    n_updates        | 18460    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.7     |
# |    ep_rew_mean      | 17.8     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1160     |
# |    fps              | 16       |
# |    time_elapsed     | 1153     |
# |    total_timesteps  | 18774    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0287   |
# |    n_updates        | 18573    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 22.1     |
# |    ep_rew_mean      | 18.1     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1164     |
# |    fps              | 16       |
# |    time_elapsed     | 1159     |
# |    total_timesteps  | 18856    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.185    |
# |    n_updates        | 18655    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.9     |
# |    ep_rew_mean      | 17.8     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1168     |
# |    fps              | 16       |
# |    time_elapsed     | 1161     |
# |    total_timesteps  | 18896    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.296    |
# |    n_updates        | 18695    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.9     |
# |    ep_rew_mean      | 17.9     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1172     |
# |    fps              | 16       |
# |    time_elapsed     | 1168     |
# |    total_timesteps  | 18992    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.125    |
# |    n_updates        | 18791    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.3     |
# |    ep_rew_mean      | 17.5     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1176     |
# |    fps              | 16       |
# |    time_elapsed     | 1172     |
# |    total_timesteps  | 19055    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.112    |
# |    n_updates        | 18854    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21       |
# |    ep_rew_mean      | 17.2     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1180     |
# |    fps              | 16       |
# |    time_elapsed     | 1177     |
# |    total_timesteps  | 19144    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.127    |
# |    n_updates        | 18943    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20.9     |
# |    ep_rew_mean      | 17.2     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1184     |
# |    fps              | 16       |
# |    time_elapsed     | 1182     |
# |    total_timesteps  | 19217    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0339   |
# |    n_updates        | 19016    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20.9     |
# |    ep_rew_mean      | 17.1     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1188     |
# |    fps              | 16       |
# |    time_elapsed     | 1189     |
# |    total_timesteps  | 19321    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0787   |
# |    n_updates        | 19120    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20.6     |
# |    ep_rew_mean      | 17       |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1192     |
# |    fps              | 16       |
# |    time_elapsed     | 1193     |
# |    total_timesteps  | 19400    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0266   |
# |    n_updates        | 19199    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 20.9     |
# |    ep_rew_mean      | 17.2     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1196     |
# |    fps              | 16       |
# |    time_elapsed     | 1201     |
# |    total_timesteps  | 19519    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0782   |
# |    n_updates        | 19318    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.6     |
# |    ep_rew_mean      | 17.7     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1200     |
# |    fps              | 16       |
# |    time_elapsed     | 1208     |
# |    total_timesteps  | 19632    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.327    |
# |    n_updates        | 19431    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.4     |
# |    ep_rew_mean      | 17.6     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1204     |
# |    fps              | 16       |
# |    time_elapsed     | 1215     |
# |    total_timesteps  | 19728    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.18     |
# |    n_updates        | 19527    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.4     |
# |    ep_rew_mean      | 17.7     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1208     |
# |    fps              | 16       |
# |    time_elapsed     | 1220     |
# |    total_timesteps  | 19810    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.0257   |
# |    n_updates        | 19609    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 21.7     |
# |    ep_rew_mean      | 18       |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1212     |
# |    fps              | 16       |
# |    time_elapsed     | 1227     |
# |    total_timesteps  | 19930    |
# | train/              |          |
# |    learning_rate    | 0.0005   |
# |    loss             | 0.144    |
# |    n_updates        | 19729    |
# ----------------------------------

# %% [markdown]
# ## Testing
#
# Visualize a few episodes

# %%
env = gym.make('highway-fast-v0', render_mode='rgb_array')
# env = record_videos(env)
for episode in trange(3, desc='Test episodes'):
    (obs, info), done = env.reset(), False
    while not done:
        action, _ = model.predict(obs, deterministic=True)
        obs, reward, done, truncated, info = env.step(int(action))
env.close()
# show_videos()
# Out:
# Test episodes:   0%|          | 0/3 [00:00<?, ?it/s]
